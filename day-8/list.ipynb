# %% [markdown]
# Lists
# ##A list is a data structure in Python that is a mutable, or changeable, ordered sequence of elements. Each element or value that is inside of a list is called an item. Just as strings are defined as characters between quotes, lists are defined by having values between square brackets [ ]

# %%
##mutable vs immutable
str1="Krish"
print(str1)
type(str1)
# Out:
# Krish
# str

# %%
str1="karthik" 
print(str1)
# Out:
# karthik

# %%
## string are immutable
str[2]="jk"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 ## string are immutable
# ----> 2 str[2]="jk"
#
# TypeError: 'type' object does not support item assignment

# %%
##list
##mutable
lst=[1,2,3,4,"krish","hello"]
print(lst)
lst[3]="karthik"
print(lst[3])
# Out:
# [1, 2, 3, 4, 'krish', 'hello']
# karthik

# %%
lst=list((1,2,3,4,5))
type(lst)
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
lst=[1,2,3,4,5]

# %%
for i in lst:
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
min(lst)
# Out:
# 1

# %%
max(lst)
# Out:
# 5

# %%
type(lst)
# Out:
# list

# %%
type([])
# Out:
# list

# %%
lst_example=[]

# %%
type(lst_example)
# Out:
# list

# %%
lst=list()

# %%
type(lst)
# Out:
# list

# %%
lst=['Maths', 'chemistry',100,200,300,402]

# %%
len(lst)
# Out:
# 6

# %%
type(lst)
# Out:
# list

# %% [markdown]
# append

# %%
lst
# Out:
# ['Maths', 'chemistry', 100, 200, 300, 402]

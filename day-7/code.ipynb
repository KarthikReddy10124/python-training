# %% [markdown]
# number methods

# %% [markdown]
# Max()

# %%
max(10,12,5,76,100)
# Out:
# 100

# %%
max(-55,-44,-33)
# Out:
# -33

# %% [markdown]
# min()

# %%
min(10,12,5,76,100)
# Out:
# 5

# %% [markdown]
# pow()

# %%
import math 
math.pow(20,5)
# Out:
# 3200000.0

# %%
import math 
math.pow(-5,-5)
# Out:
# -0.00032

# %%
math.pow(3,2)
# Out:
# 9.0

# %% [markdown]
# sqrt()

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.sqrt(7)
# Out:
# 2.6457513110645907

# %% [markdown]
# Triggnometric functions

# %%
import math
math.sin(0)
# Out:
# 0.0

# %%
math.sin(10)
# Out:
# -0.5440211108893698

# %%
math.cos(90)
# Out:
# -0.4480736161291701

# %%
math.cos(0)
# Out:
# 1.0

# %%
math.tan(0)
# Out:
# 0.0

# %%
math.tan(45)
# Out:
# 1.6197751905438615

# %% [markdown]
# hypot()

# %%
math.hypot(2,3)
# Out:
# 3.605551275463989

# %%
result1 = math.modf(3.5)
print("Result 1:", result1)
# Out:
# Result 1: (0.5, 3.0)

# %%
num = int(input("Enter the number: "))

if num > 1:
    for i in range(2, num):
        if (num % i) == 0: 
            print("The given number is not prime")
            break
    else:
        print("The given number is prime")
else:
    print("The given number is not prime")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 num = int(input("Enter the number: "))
#       2
# ----> 3 if num > 1:
#       4     for i in range(2, num):
#       5         if (num % i) == 0:
#       6             print("The given number is not prime")
#
# TypeError: '>' not supported between instances of 'str' and 'int'
